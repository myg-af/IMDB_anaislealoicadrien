# %% [markdown]
# # 1/ import package

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import urllib.request
import sqlite3

# %% [markdown]
# # 2 / Importer le site avec les 5 pages
# ### création d'une liste url de page 1 à 201 avec un saut de 5O( 50 elèments par pages)

# %%
urls= []
for i in range(1, 202, 50):
    url=f"https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start={i}&ref_=adv_nxt" 
    urls.append(url)
urls
# Out:
# ['https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=1&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=51&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=101&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=151&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=201&ref_=adv_nxt']

# %% [markdown]
# ## if response(l'object) est ok, écrit le code 2OO = no problem
# ### requests pour placer le contenu de la page web dans la variable df.

# %%
for url in urls :
    pagelink = urllib.request.urlopen(url)
    soup = BeautifulSoup(pagelink, 'html.parser')
    response = requests.get(url)
    
    if response.ok:
        print(response)
    df = requests.get(url)
    print(url)
# Out:
# <Response [200]>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=1&ref_=adv_nxt
# <Response [200]>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=51&ref_=adv_nxt
# <Response [200]>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=101&ref_=adv_nxt
# <Response [200]>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=151&ref_=adv_nxt
# <Response [200]>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=201&ref_=adv_nxt

# %% [markdown]
# ### Affiche l'ensemble des headers

# %%
#df.headers

# %% [markdown]
# ### Affiche les balises

# %%
#df.content

# %% [markdown]
# ### Ecrit le code html de la page

# %%
#print(df.text)

# %% [markdown]
# ### Affiche le code html mais maintenant possiblilité de faire des sélections dans la page

# %%
soup = BeautifulSoup
print(soup)
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# ###  Rend le contenu facilement interrogeable par les différentes fonctions offertes par BeautifulSoup. Ces fonctions vont pouvoir être appliquées à la variable soup.

# %%
soup = BeautifulSoup(df.text,"html.parser")

# %% [markdown]
# ### Affiche le titre .find pour localiser un élèment en fonction d'un selecteur CSS

# %%
title=soup.find("title")
print(title)
# Out:
# <title>IMDb "Top 250"
# (Sorted by IMDb Rating Descending) - IMDb</title>

# %% [markdown]
# ### Selection de l'elèment d'une class (html) dans le site

# %%
variable = soup.find_all('div', attrs={'class': 'lister-item mode-advanced'})
print(variable)
# Out:
# [<div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0395169"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0395169/"> <img alt="Hôtel Rwanda" class="loadlate" data-tconst="tt0395169" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZGJjYmIzZmQtNWE4Yy00ZGVmLWJkZGEtMzUzNmQ4ZWFlMjRhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">201.</span>
# <a href="/title/tt0395169/">Hôtel Rwanda</a>
# <span class="lister-item-year text-muted unbold">(2004)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous Public</span>
# <span class="ghost">|</span>
# <span class="runtime">121 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Biography, Drama, History            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0395169" id="urv_tt0395169">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0395169">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0395169|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (338,096 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="338096" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0395169/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">79        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
# <a href="/name/nm1850588">Paul Rusesabagina</a>, a hotel manager, houses over a thousand Tutsi refugees during their struggle against the Hutu militia in Rwanda, Africa.</p>
# <p class="">
#     Director:
# <a href="/name/nm0313623/">Terry George</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000332/">Don Cheadle</a>,
# <a href="/name/nm0645683/">Sophie Okonedo</a>,
# <a href="/name/nm0001618/">Joaquin Phoenix</a>,
# <a href="/name/nm1796730/">Xolani Mali</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="338096" name="nv">338,096</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="23,530,892" name="nv">$23.53M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0381681"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0381681/"> <img alt="Before Sunset" class="loadlate" data-tconst="tt0381681" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTQ1MjAwNTM5Ml5BMl5BanBnXkFtZTYwNDM0MTc3._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">202.</span>
# <a href="/title/tt0381681/">Before Sunset</a>
# <span class="lister-item-year text-muted unbold">(2004)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">80 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Drama, Romance            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0381681" id="urv_tt0381681">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0381681">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0381681|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (241,107 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="241107" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0381681/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">90        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     Nine years after Jesse and Celine first met, they encounter each other again on the French leg of Jesse's book tour.</p>
# <p class="">
#     Director:
# <a href="/name/nm0000500/">Richard Linklater</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000160/">Ethan Hawke</a>,
# <a href="/name/nm0000365/">Julie Delpy</a>,
# <a href="/name/nm0229943/">Vernon Dobtcheff</a>,
# <a href="/name/nm1195302/">Louise Lemoine Torrès</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="241107" name="nv">241,107</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="5,820,649" name="nv">$5.82M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0374887"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0374887/"> <img alt="Munna Bhai M.B.B.S." class="loadlate" data-tconst="tt0374887" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMzQ4MTBlYTQtMzJkYS00OGNjLTk1MWYtNzQ0OTQ0OWEyOWU1XkEyXkFqcGdeQXVyNDgyODgxNjE@._V1_UY98_CR1,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">203.</span>
# <a href="/title/tt0374887/">Munna Bhai M.B.B.S.</a>
# <span class="lister-item-year text-muted unbold">(2003)</span>
# </h3>
# <p class="text-muted">
# <span class="runtime">156 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Comedy, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0374887" id="urv_tt0374887">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0374887">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0374887|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (74,993 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="74993" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0374887/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# </div>
# <p class="text-muted">
#     A gangster sets out to fulfill his father's dream of becoming a doctor.</p>
# <p class="">
#     Director:
# <a href="/name/nm0386246/">Rajkumar Hirani</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0004569/">Sanjay Dutt</a>,
# <a href="/name/nm0451174/">Arshad Warsi</a>,
# <a href="/name/nm0961737/">Gracy Singh</a>,
# <a href="/name/nm0004570/">Sunil Dutt</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="74993" name="nv">74,993</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0353969"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0353969/"> <img alt="Memories of Murder" class="loadlate" data-tconst="tt0353969" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BOGViNTg4YTktYTQ2Ni00MTU0LTk2NWUtMTI4OTc1YTM0NzQ2XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">204.</span>
# <a href="/title/tt0353969/">Memories of Murder</a>
# <span class="lister-item-year text-muted unbold">(2003)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">131 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Crime, Drama, Mystery            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0353969" id="urv_tt0353969">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0353969">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0353969|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (146,971 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="146971" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0353969/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">82        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     In a small Korean province in 1986, two detectives struggle with the case of multiple young women being found raped and murdered by an unknown culprit.</p>
# <p class="">
#     Director:
# <a href="/name/nm0094435/">Bong Joon Ho</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0814280/">Kang-ho Song</a>,
# <a href="/name/nm1235292/">Kim Sang-kyung</a>,
# <a href="/name/nm1323287/">Roe-ha Kim</a>,
# <a href="/name/nm1138201/">Jae-ho Song</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="146971" name="nv">146,971</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="14,131" name="nv">$0.01M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0266697"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0266697/"> <img alt="Kill Bill: Volume I" class="loadlate" data-tconst="tt0266697" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNzM3NDFhYTAtYmU5Mi00NGRmLTljYjgtMDkyODQ4MjNkMGY2XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">205.</span>
# <a href="/title/tt0266697/">Kill Bill: Volume I</a>
# <span class="lister-item-year text-muted unbold">(2003)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">16</span>
# <span class="ghost">|</span>
# <span class="runtime">111 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Action, Crime, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0266697" id="urv_tt0266697">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0266697">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0266697|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (1,017,018 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="1017018" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0266697/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">69        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     After awakening from a four-year coma, a former assassin wreaks vengeance on the team of assassins who betrayed her.</p>
# <p class="">
#     Director:
# <a href="/name/nm0000233/">Quentin Tarantino</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000235/">Uma Thurman</a>,
# <a href="/name/nm0001016/">David Carradine</a>,
# <a href="/name/nm0000435/">Daryl Hannah</a>,
# <a href="/name/nm0000514/">Michael Madsen</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="1017018" name="nv">1,017,018</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="70,099,045" name="nv">$70.10M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0266543"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0266543/"> <img alt="Le Monde de Nemo" class="loadlate" data-tconst="tt0266543" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZTAzNWZlNmUtZDEzYi00ZjA5LWIwYjEtZGM1NWE1MjE4YWRhXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">206.</span>
# <a href="/title/tt0266543/">Le Monde de Nemo</a>
# <span class="lister-item-year text-muted unbold">(2003)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">100 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Animation, Adventure, Comedy            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0266543" id="urv_tt0266543">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0266543">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0266543|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (963,197 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="963197" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0266543/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">90        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     After his son is captured in the Great Barrier Reef and taken to Sydney, a timid clownfish sets out on a journey to bring him home.</p>
# <p class="">
#     Directors:
# <a href="/name/nm0004056/">Andrew Stanton</a>,
# <a href="/name/nm0881279/">Lee Unkrich</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000983/">Albert Brooks</a>,
# <a href="/name/nm0001122/">Ellen DeGeneres</a>,
# <a href="/name/nm1071252/">Alexander Gould</a>,
# <a href="/name/nm0000353/">Willem Dafoe</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="963197" name="nv">963,197</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="380,843,261" name="nv">$380.84M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0264464"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0264464/"> <img alt="Arrête-moi si tu peux" class="loadlate" data-tconst="tt0264464" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTY5MzYzNjc5NV5BMl5BanBnXkFtZTYwNTUyNTc2._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">207.</span>
# <a href="/title/tt0264464/">Arrête-moi si tu peux</a>
# <span class="lister-item-year text-muted unbold">(2002)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">141 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Biography, Crime, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0264464" id="urv_tt0264464">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0264464">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0264464|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (853,836 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="853836" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0264464/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">75        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     Barely 21 yet, Frank is a skilled forger who has passed as a doctor, lawyer and pilot. FBI agent Carl becomes obsessed with tracking down the con man, who only revels in the pursuit.</p>
# <p class="">
#     Director:
# <a href="/name/nm0000229/">Steven Spielberg</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000138/">Leonardo DiCaprio</a>,
# <a href="/name/nm0000158/">Tom Hanks</a>,
# <a href="/name/nm0000686/">Christopher Walken</a>,
# <a href="/name/nm0000640/">Martin Sheen</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="853836" name="nv">853,836</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="164,615,351" name="nv">$164.62M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0245712"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0245712/"> <img alt="Amours chiennes" class="loadlate" data-tconst="tt0245712" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMjQxMWJhMzMtMzllZi00NzMwLTllYjktNTcwZmU4ZmU3NTA0XkEyXkFqcGdeQXVyMTAzMDM4MjM0._V1_UY98_CR3,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">208.</span>
# <a href="/title/tt0245712/">Amours chiennes</a>
# <span class="lister-item-year text-muted unbold">(2000)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">12</span>
# <span class="ghost">|</span>
# <span class="runtime">154 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Drama, Thriller            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0245712" id="urv_tt0245712">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0245712">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0245712|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (226,750 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="226750" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0245712/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">83        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     A horrific car accident connects three stories, each involving characters dealing with loss, regret, and life's harsh realities, all in the name of love.</p>
# <p class="">
#     Director:
# <a href="/name/nm0327944/">Alejandro G. Iñárritu</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0248408/">Emilio Echevarría</a>,
# <a href="/name/nm0305558/">Gael García Bernal</a>,
# <a href="/name/nm0865949/">Goya Toledo</a>,
# <a href="/name/nm0346270/">Álvaro Guerrero</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="226750" name="nv">226,750</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="5,383,834" name="nv">$5.38M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0198781"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0198781/"> <img alt="Monstres &amp; Cie" class="loadlate" data-tconst="tt0198781" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTY1NTI0ODUyOF5BMl5BanBnXkFtZTgwNTEyNjQ0MDE@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">209.</span>
# <a href="/title/tt0198781/">Monstres &amp; Cie</a>
# <span class="lister-item-year text-muted unbold">(2001)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">92 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Animation, Adventure, Comedy            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0198781" id="urv_tt0198781">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0198781">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0198781|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (828,919 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="828919" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0198781/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">79        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     In order to power the city, monsters have to scare children so that they scream. However, the children are toxic to the monsters, and after a child gets through, two monsters realize things may not be what they think.</p>
# <p class="">
#     Directors:
# <a href="/name/nm0230032/">Pete Docter</a>,
# <a href="/name/nm0798899/">David Silverman</a>,
# <a href="/name/nm0881279/">Lee Unkrich</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000345/">Billy Crystal</a>,
# <a href="/name/nm0000422/">John Goodman</a>,
# <a href="/name/nm0316701/">Mary Gibbs</a>,
# <a href="/name/nm0000114/">Steve Buscemi</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="828919" name="nv">828,919</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="289,916,256" name="nv">$289.92M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0167404"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0167404/"> <img alt="Sixième sens" class="loadlate" data-tconst="tt0167404" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMWM4NTFhYjctNzUyNi00NGMwLTk3NTYtMDIyNTZmMzRlYmQyXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">210.</span>
# <a href="/title/tt0167404/">Sixième sens</a>
# <span class="lister-item-year text-muted unbold">(1999)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">12</span>
# <span class="ghost">|</span>
# <span class="runtime">107 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Drama, Mystery, Thriller            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0167404" id="urv_tt0167404">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0167404">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0167404|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (922,646 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="922646" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0167404/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">64        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     A boy who communicates with spirits seeks the help of a disheartened child psychologist.</p>
# <p class="">
#     Director:
# <a href="/name/nm0796117/">M. Night Shyamalan</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000246/">Bruce Willis</a>,
# <a href="/name/nm0005286/">Haley Joel Osment</a>,
# <a href="/name/nm0001057/">Toni Collette</a>,
# <a href="/name/nm0931404/">Olivia Williams</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="922646" name="nv">922,646</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="293,506,292" name="nv">$293.51M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0120382"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0120382/"> <img alt="The Truman Show" class="loadlate" data-tconst="tt0120382" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMDIzODcyY2EtMmY2MC00ZWVlLTgwMzAtMjQwOWUyNmJjNTYyXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">211.</span>
# <a href="/title/tt0120382/">The Truman Show</a>
# <span class="lister-item-year text-muted unbold">(1998)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">103 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Comedy, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0120382" id="urv_tt0120382">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0120382">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0120382|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (960,088 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="960088" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0120382/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">90        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     An insurance salesman discovers his whole life is actually a reality TV show.</p>
# <p class="">
#     Director:
# <a href="/name/nm0001837/">Peter Weir</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000120/">Jim Carrey</a>,
# <a href="/name/nm0000438/">Ed Harris</a>,
# <a href="/name/nm0001473/">Laura Linney</a>,
# ...
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="294196" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0031381/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">97        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     A manipulative woman and a roguish man conduct a turbulent romance during the American Civil War and Reconstruction periods.</p>
# <p class="">
#     Directors:
# <a href="/name/nm0281808/">Victor Fleming</a>,
# <a href="/name/nm0002030/">George Cukor</a>,
# <a href="/name/nm0939992/">Sam Wood</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000022/">Clark Gable</a>,
# <a href="/name/nm0000046/">Vivien Leigh</a>,
# <a href="/name/nm0593775/">Thomas Mitchell</a>,
# <a href="/name/nm0641966/">Barbara O'Neil</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="294196" name="nv">294,196</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="198,676,459" name="nv">$198.68M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0025316"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0025316/"> <img alt="New York - Miami" class="loadlate" data-tconst="tt0025316" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYzJmMWE5NjAtNWMyZS00NmFiLWIwMDgtZDE2NzczYWFhNzIzXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">248.</span>
# <a href="/title/tt0025316/">New York - Miami</a>
# <span class="lister-item-year text-muted unbold">(1934)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">105 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Comedy, Romance            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0025316" id="urv_tt0025316">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0025316">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0025316|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (95,833 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="95833" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0025316/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">87        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     A renegade reporter and a crazy young heiress meet on a bus heading for New York, and end up stuck with each other when the bus leaves them behind at one of the stops.</p>
# <p class="">
#     Director:
# <a href="/name/nm0001008/">Frank Capra</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000022/">Clark Gable</a>,
# <a href="/name/nm0001055/">Claudette Colbert</a>,
# <a href="/name/nm0175369/">Walter Connolly</a>,
# <a href="/name/nm0439850/">Roscoe Karns</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="95833" name="nv">95,833</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="4,360,000" name="nv">$4.36M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0019254"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0019254/"> <img alt="La passion de Jeanne d'Arc" class="loadlate" data-tconst="tt0019254" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNjBjNDJiYTUtOWY0OS00OGVmLTg2YzctMTE0NzVhODM1ZWJmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">249.</span>
# <a href="/title/tt0019254/">La passion de Jeanne d'Arc</a>
# <span class="lister-item-year text-muted unbold">(1928)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Not Rated</span>
# <span class="ghost">|</span>
# <span class="runtime">110 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Biography, Drama, History            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0019254" id="urv_tt0019254">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0019254">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0019254|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (49,041 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="49041" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0019254/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# </div>
# <p class="text-muted">
#     In 1431, Jeanne d'Arc is placed on trial on charges of heresy. The ecclesiastical jurists attempt to force Jeanne to recant her claims of holy visions.</p>
# <p class="">
#     Director:
# <a href="/name/nm0003433/">Carl Theodor Dreyer</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0266029/">Maria Falconetti</a>,
# <a href="/name/nm0798564/">Eugene Silvain</a>,
# <a href="/name/nm0075551/">André Berley</a>,
# <a href="/name/nm0776914/">Maurice Schutz</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="49041" name="nv">49,041</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="21,877" name="nv">$0.02M</span>
# </p>
# </div>
# </div>, <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0017925"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0017925/"> <img alt="Le mécano de la Générale" class="loadlate" data-tconst="tt0017925" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYmRiMDFlYjYtOTMwYy00OGY2LWE0Y2QtYzQxOGNhZmUwNTIxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">250.</span>
# <a href="/title/tt0017925/">Le mécano de la Générale</a>
# <span class="lister-item-year text-muted unbold">(1926)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">67 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Action, Adventure, Comedy            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0017925" id="urv_tt0017925">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0017925">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0017925|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (82,640 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="82640" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0017925/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# </div>
# <p class="text-muted">
#     When Union spies steal an engineer's beloved locomotive, he pursues it single-handedly and straight through enemy lines.</p>
# <p class="">
#     Directors:
# <a href="/name/nm0115669/">Clyde Bruckman</a>,
# <a href="/name/nm0000036/">Buster Keaton</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000036/">Buster Keaton</a>,
# <a href="/name/nm0533045/">Marion Mack</a>,
# <a href="/name/nm0147070/">Glen Cavender</a>,
# <a href="/name/nm0267650/">Jim Farley</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="82640" name="nv">82,640</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="1,033,895" name="nv">$1.03M</span>
# </p>
# </div>
# </div>]

# %% [markdown]
# ### le contenu qui nous intéresse se trouve dans une balise très commune donc faire une boucle for
# ### séparer les élèments par des -----

# %%
for i in variable:
    print(i)
    print("-"*100)
# Out:
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0395169"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0395169/"> <img alt="Hôtel Rwanda" class="loadlate" data-tconst="tt0395169" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZGJjYmIzZmQtNWE4Yy00ZGVmLWJkZGEtMzUzNmQ4ZWFlMjRhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">201.</span>
# <a href="/title/tt0395169/">Hôtel Rwanda</a>
# <span class="lister-item-year text-muted unbold">(2004)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous Public</span>
# <span class="ghost">|</span>
# <span class="runtime">121 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Biography, Drama, History            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0395169" id="urv_tt0395169">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0395169">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0395169|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (338,096 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="338096" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0395169/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">79        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
# <a href="/name/nm1850588">Paul Rusesabagina</a>, a hotel manager, houses over a thousand Tutsi refugees during their struggle against the Hutu militia in Rwanda, Africa.</p>
# <p class="">
#     Director:
# <a href="/name/nm0313623/">Terry George</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000332/">Don Cheadle</a>,
# <a href="/name/nm0645683/">Sophie Okonedo</a>,
# <a href="/name/nm0001618/">Joaquin Phoenix</a>,
# <a href="/name/nm1796730/">Xolani Mali</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="338096" name="nv">338,096</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="23,530,892" name="nv">$23.53M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0381681"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0381681/"> <img alt="Before Sunset" class="loadlate" data-tconst="tt0381681" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTQ1MjAwNTM5Ml5BMl5BanBnXkFtZTYwNDM0MTc3._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">202.</span>
# <a href="/title/tt0381681/">Before Sunset</a>
# <span class="lister-item-year text-muted unbold">(2004)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">80 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Drama, Romance            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0381681" id="urv_tt0381681">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0381681">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0381681|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (241,107 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="241107" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0381681/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">90        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     Nine years after Jesse and Celine first met, they encounter each other again on the French leg of Jesse's book tour.</p>
# <p class="">
#     Director:
# <a href="/name/nm0000500/">Richard Linklater</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000160/">Ethan Hawke</a>,
# <a href="/name/nm0000365/">Julie Delpy</a>,
# <a href="/name/nm0229943/">Vernon Dobtcheff</a>,
# <a href="/name/nm1195302/">Louise Lemoine Torrès</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="241107" name="nv">241,107</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="5,820,649" name="nv">$5.82M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0374887"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0374887/"> <img alt="Munna Bhai M.B.B.S." class="loadlate" data-tconst="tt0374887" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMzQ4MTBlYTQtMzJkYS00OGNjLTk1MWYtNzQ0OTQ0OWEyOWU1XkEyXkFqcGdeQXVyNDgyODgxNjE@._V1_UY98_CR1,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">203.</span>
# <a href="/title/tt0374887/">Munna Bhai M.B.B.S.</a>
# <span class="lister-item-year text-muted unbold">(2003)</span>
# </h3>
# <p class="text-muted">
# <span class="runtime">156 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Comedy, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0374887" id="urv_tt0374887">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0374887">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0374887|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (74,993 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="74993" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0374887/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# </div>
# <p class="text-muted">
#     A gangster sets out to fulfill his father's dream of becoming a doctor.</p>
# <p class="">
#     Director:
# <a href="/name/nm0386246/">Rajkumar Hirani</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0004569/">Sanjay Dutt</a>,
# <a href="/name/nm0451174/">Arshad Warsi</a>,
# <a href="/name/nm0961737/">Gracy Singh</a>,
# <a href="/name/nm0004570/">Sunil Dutt</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="74993" name="nv">74,993</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0353969"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0353969/"> <img alt="Memories of Murder" class="loadlate" data-tconst="tt0353969" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BOGViNTg4YTktYTQ2Ni00MTU0LTk2NWUtMTI4OTc1YTM0NzQ2XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">204.</span>
# <a href="/title/tt0353969/">Memories of Murder</a>
# <span class="lister-item-year text-muted unbold">(2003)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">131 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Crime, Drama, Mystery            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0353969" id="urv_tt0353969">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0353969">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0353969|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (146,971 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="146971" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0353969/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">82        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     In a small Korean province in 1986, two detectives struggle with the case of multiple young women being found raped and murdered by an unknown culprit.</p>
# <p class="">
#     Director:
# <a href="/name/nm0094435/">Bong Joon Ho</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0814280/">Kang-ho Song</a>,
# <a href="/name/nm1235292/">Kim Sang-kyung</a>,
# <a href="/name/nm1323287/">Roe-ha Kim</a>,
# <a href="/name/nm1138201/">Jae-ho Song</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="146971" name="nv">146,971</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="14,131" name="nv">$0.01M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0266697"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0266697/"> <img alt="Kill Bill: Volume I" class="loadlate" data-tconst="tt0266697" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNzM3NDFhYTAtYmU5Mi00NGRmLTljYjgtMDkyODQ4MjNkMGY2XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">205.</span>
# <a href="/title/tt0266697/">Kill Bill: Volume I</a>
# <span class="lister-item-year text-muted unbold">(2003)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">16</span>
# <span class="ghost">|</span>
# <span class="runtime">111 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Action, Crime, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0266697" id="urv_tt0266697">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0266697">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0266697|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (1,017,018 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="1017018" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0266697/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">69        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     After awakening from a four-year coma, a former assassin wreaks vengeance on the team of assassins who betrayed her.</p>
# <p class="">
#     Director:
# <a href="/name/nm0000233/">Quentin Tarantino</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000235/">Uma Thurman</a>,
# <a href="/name/nm0001016/">David Carradine</a>,
# <a href="/name/nm0000435/">Daryl Hannah</a>,
# <a href="/name/nm0000514/">Michael Madsen</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="1017018" name="nv">1,017,018</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="70,099,045" name="nv">$70.10M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0266543"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0266543/"> <img alt="Le Monde de Nemo" class="loadlate" data-tconst="tt0266543" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZTAzNWZlNmUtZDEzYi00ZjA5LWIwYjEtZGM1NWE1MjE4YWRhXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">206.</span>
# <a href="/title/tt0266543/">Le Monde de Nemo</a>
# <span class="lister-item-year text-muted unbold">(2003)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">100 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Animation, Adventure, Comedy            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0266543" id="urv_tt0266543">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0266543">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0266543|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (963,197 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="963197" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0266543/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">90        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     After his son is captured in the Great Barrier Reef and taken to Sydney, a timid clownfish sets out on a journey to bring him home.</p>
# <p class="">
#     Directors:
# <a href="/name/nm0004056/">Andrew Stanton</a>,
# <a href="/name/nm0881279/">Lee Unkrich</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000983/">Albert Brooks</a>,
# <a href="/name/nm0001122/">Ellen DeGeneres</a>,
# <a href="/name/nm1071252/">Alexander Gould</a>,
# <a href="/name/nm0000353/">Willem Dafoe</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="963197" name="nv">963,197</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="380,843,261" name="nv">$380.84M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0264464"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0264464/"> <img alt="Arrête-moi si tu peux" class="loadlate" data-tconst="tt0264464" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTY5MzYzNjc5NV5BMl5BanBnXkFtZTYwNTUyNTc2._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">207.</span>
# <a href="/title/tt0264464/">Arrête-moi si tu peux</a>
# <span class="lister-item-year text-muted unbold">(2002)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">141 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Biography, Crime, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0264464" id="urv_tt0264464">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0264464">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0264464|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (853,836 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="853836" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0264464/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">75        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     Barely 21 yet, Frank is a skilled forger who has passed as a doctor, lawyer and pilot. FBI agent Carl becomes obsessed with tracking down the con man, who only revels in the pursuit.</p>
# <p class="">
#     Director:
# <a href="/name/nm0000229/">Steven Spielberg</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000138/">Leonardo DiCaprio</a>,
# <a href="/name/nm0000158/">Tom Hanks</a>,
# <a href="/name/nm0000686/">Christopher Walken</a>,
# <a href="/name/nm0000640/">Martin Sheen</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="853836" name="nv">853,836</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="164,615,351" name="nv">$164.62M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0245712"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0245712/"> <img alt="Amours chiennes" class="loadlate" data-tconst="tt0245712" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMjQxMWJhMzMtMzllZi00NzMwLTllYjktNTcwZmU4ZmU3NTA0XkEyXkFqcGdeQXVyMTAzMDM4MjM0._V1_UY98_CR3,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">208.</span>
# <a href="/title/tt0245712/">Amours chiennes</a>
# <span class="lister-item-year text-muted unbold">(2000)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">12</span>
# <span class="ghost">|</span>
# <span class="runtime">154 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Drama, Thriller            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0245712" id="urv_tt0245712">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0245712">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0245712|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (226,750 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="226750" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0245712/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">83        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     A horrific car accident connects three stories, each involving characters dealing with loss, regret, and life's harsh realities, all in the name of love.</p>
# <p class="">
#     Director:
# <a href="/name/nm0327944/">Alejandro G. Iñárritu</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0248408/">Emilio Echevarría</a>,
# <a href="/name/nm0305558/">Gael García Bernal</a>,
# <a href="/name/nm0865949/">Goya Toledo</a>,
# <a href="/name/nm0346270/">Álvaro Guerrero</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="226750" name="nv">226,750</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="5,383,834" name="nv">$5.38M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0198781"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0198781/"> <img alt="Monstres &amp; Cie" class="loadlate" data-tconst="tt0198781" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTY1NTI0ODUyOF5BMl5BanBnXkFtZTgwNTEyNjQ0MDE@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">209.</span>
# <a href="/title/tt0198781/">Monstres &amp; Cie</a>
# <span class="lister-item-year text-muted unbold">(2001)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">92 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Animation, Adventure, Comedy            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0198781" id="urv_tt0198781">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0198781">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0198781|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (828,919 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="828919" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0198781/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">79        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     In order to power the city, monsters have to scare children so that they scream. However, the children are toxic to the monsters, and after a child gets through, two monsters realize things may not be what they think.</p>
# <p class="">
#     Directors:
# <a href="/name/nm0230032/">Pete Docter</a>,
# <a href="/name/nm0798899/">David Silverman</a>,
# <a href="/name/nm0881279/">Lee Unkrich</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000345/">Billy Crystal</a>,
# <a href="/name/nm0000422/">John Goodman</a>,
# <a href="/name/nm0316701/">Mary Gibbs</a>,
# <a href="/name/nm0000114/">Steve Buscemi</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="828919" name="nv">828,919</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="289,916,256" name="nv">$289.92M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0167404"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0167404/"> <img alt="Sixième sens" class="loadlate" data-tconst="tt0167404" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMWM4NTFhYjctNzUyNi00NGMwLTk3NTYtMDIyNTZmMzRlYmQyXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">210.</span>
# <a href="/title/tt0167404/">Sixième sens</a>
# <span class="lister-item-year text-muted unbold">(1999)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">12</span>
# <span class="ghost">|</span>
# <span class="runtime">107 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Drama, Mystery, Thriller            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0167404" id="urv_tt0167404">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0167404">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0167404|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (922,646 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="922646" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0167404/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">64        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     A boy who communicates with spirits seeks the help of a disheartened child psychologist.</p>
# <p class="">
#     Director:
# <a href="/name/nm0796117/">M. Night Shyamalan</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000246/">Bruce Willis</a>,
# <a href="/name/nm0005286/">Haley Joel Osment</a>,
# <a href="/name/nm0001057/">Toni Collette</a>,
# <a href="/name/nm0931404/">Olivia Williams</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="922646" name="nv">922,646</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="293,506,292" name="nv">$293.51M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0120382"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0120382/"> <img alt="The Truman Show" class="loadlate" data-tconst="tt0120382" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMDIzODcyY2EtMmY2MC00ZWVlLTgwMzAtMjQwOWUyNmJjNTYyXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">211.</span>
# <a href="/title/tt0120382/">The Truman Show</a>
# <span class="lister-item-year text-muted unbold">(1998)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">103 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Comedy, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0120382" id="urv_tt0120382">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0120382">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0120382|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (960,088 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="960088" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# ...
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0031381/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">97        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     A manipulative woman and a roguish man conduct a turbulent romance during the American Civil War and Reconstruction periods.</p>
# <p class="">
#     Directors:
# <a href="/name/nm0281808/">Victor Fleming</a>,
# <a href="/name/nm0002030/">George Cukor</a>,
# <a href="/name/nm0939992/">Sam Wood</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000022/">Clark Gable</a>,
# <a href="/name/nm0000046/">Vivien Leigh</a>,
# <a href="/name/nm0593775/">Thomas Mitchell</a>,
# <a href="/name/nm0641966/">Barbara O'Neil</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="294196" name="nv">294,196</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="198,676,459" name="nv">$198.68M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0025316"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0025316/"> <img alt="New York - Miami" class="loadlate" data-tconst="tt0025316" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYzJmMWE5NjAtNWMyZS00NmFiLWIwMDgtZDE2NzczYWFhNzIzXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">248.</span>
# <a href="/title/tt0025316/">New York - Miami</a>
# <span class="lister-item-year text-muted unbold">(1934)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">105 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Comedy, Romance            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0025316" id="urv_tt0025316">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0025316">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0025316|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (95,833 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="95833" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0025316/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">87        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
#     A renegade reporter and a crazy young heiress meet on a bus heading for New York, and end up stuck with each other when the bus leaves them behind at one of the stops.</p>
# <p class="">
#     Director:
# <a href="/name/nm0001008/">Frank Capra</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000022/">Clark Gable</a>,
# <a href="/name/nm0001055/">Claudette Colbert</a>,
# <a href="/name/nm0175369/">Walter Connolly</a>,
# <a href="/name/nm0439850/">Roscoe Karns</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="95833" name="nv">95,833</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="4,360,000" name="nv">$4.36M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0019254"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0019254/"> <img alt="La passion de Jeanne d'Arc" class="loadlate" data-tconst="tt0019254" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNjBjNDJiYTUtOWY0OS00OGVmLTg2YzctMTE0NzVhODM1ZWJmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">249.</span>
# <a href="/title/tt0019254/">La passion de Jeanne d'Arc</a>
# <span class="lister-item-year text-muted unbold">(1928)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Not Rated</span>
# <span class="ghost">|</span>
# <span class="runtime">110 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Biography, Drama, History            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0019254" id="urv_tt0019254">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0019254">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0019254|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (49,041 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="49041" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0019254/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# </div>
# <p class="text-muted">
#     In 1431, Jeanne d'Arc is placed on trial on charges of heresy. The ecclesiastical jurists attempt to force Jeanne to recant her claims of holy visions.</p>
# <p class="">
#     Director:
# <a href="/name/nm0003433/">Carl Theodor Dreyer</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0266029/">Maria Falconetti</a>,
# <a href="/name/nm0798564/">Eugene Silvain</a>,
# <a href="/name/nm0075551/">André Berley</a>,
# <a href="/name/nm0776914/">Maurice Schutz</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="49041" name="nv">49,041</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="21,877" name="nv">$0.02M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0017925"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt0017925/"> <img alt="Le mécano de la Générale" class="loadlate" data-tconst="tt0017925" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYmRiMDFlYjYtOTMwYy00OGY2LWE0Y2QtYzQxOGNhZmUwNTIxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">250.</span>
# <a href="/title/tt0017925/">Le mécano de la Générale</a>
# <span class="lister-item-year text-muted unbold">(1926)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">Tous publics</span>
# <span class="ghost">|</span>
# <span class="runtime">67 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Action, Adventure, Comedy            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0017925" id="urv_tt0017925">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0017925">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0017925|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (82,640 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="82640" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt0017925/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# </div>
# <p class="text-muted">
#     When Union spies steal an engineer's beloved locomotive, he pursues it single-handedly and straight through enemy lines.</p>
# <p class="">
#     Directors:
# <a href="/name/nm0115669/">Clyde Bruckman</a>,
# <a href="/name/nm0000036/">Buster Keaton</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000036/">Buster Keaton</a>,
# <a href="/name/nm0533045/">Marion Mack</a>,
# <a href="/name/nm0147070/">Glen Cavender</a>,
# <a href="/name/nm0267650/">Jim Farley</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="82640" name="nv">82,640</span>
# <span class="ghost">|</span> <span class="text-muted">Gross:</span>
# <span data-value="1,033,895" name="nv">$1.03M</span>
# </p>
# </div>
# </div>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3 / WEB SCRAPING
# ### boucle sur les 5 pages

# %%
for url in urls :
    print(url)
    pagelink = urllib.request.urlopen(url)

    soup = BeautifulSoup(pagelink, 'html.parser')
    movies = soup.find_all('div', attrs={'class': 'lister-item mode-advanced'})
    

    print(type(movies))
# Out:
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=1&ref_=adv_nxt
# <class 'bs4.element.ResultSet'>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=51&ref_=adv_nxt
# <class 'bs4.element.ResultSet'>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=101&ref_=adv_nxt
# <class 'bs4.element.ResultSet'>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=151&ref_=adv_nxt
# <class 'bs4.element.ResultSet'>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=201&ref_=adv_nxt
# <class 'bs4.element.ResultSet'>

# %% [markdown]
# ### Selection des élèments importants: Titre / Année /Stars /Nombre de vote/Réalisateur/Recette

# %%
movies_id =0
for url in urls :
    pagelink = urllib.request.urlopen(url)
    soup = BeautifulSoup(pagelink, 'html.parser')
    response = requests.get(url)
    
    if response.ok:
        print(response)
    df = requests.get(url)
    
    print(url)
    pagelink = urllib.request.urlopen(url)

    soup = BeautifulSoup(pagelink, 'html.parser')
    movies = soup.find_all('div', attrs={'class': 'lister-item mode-advanced'})
    
    for i in movies:
        movies_id = movies_id + 1
        i = list(i)

        print(f"id > {movies_id}")
        #print(i[3])
        title = i[3].find('img', attrs={'class': 'loadlate'})['alt']
        print(f"title > {title}")

        #print(i[5])
        year = i[5].find('span', attrs={'class': 'lister-item-year text-muted unbold'})
        year = year.text
        year = year.replace("(","")
        year = year.replace(")","")
        print(f"year > {year}")

        rating = i[5].find('div', attrs={'class': 'inline-block ratings-imdb-rating'})
        rating = rating.text
        rating= rating.strip()
        print(f"rating > {rating}")

        nb_de_vote = i[5].find('meta', attrs={'itemprop': 'ratingCount'})['content']
        print(f"nb_de_vote > {nb_de_vote}")

        value = i[5].find_all('span')[-1:][0]["data-value"].replace(",","")
        print(value)

        #value = i[5] #on récup index 5 i (i = liste)
        #print(value)
        #value = value.find_all('span') #on cherche tout les splan
        #print(value)
        #value = value[-1:] #dernier span element de la liste
        #print(value)
        #value = value[0] # on prend le seul élement de la liste
        #print(value)
        #value = value["data-value"]# on recup la valeur de data value
        #print(value)
        #value = value.replace(",","") #on supprime les virgules
        #print(value)

        realisator = i[5].find_all('p', attrs={'class': ''})
        realisator = str(realisator[0]).split('|')[0]
        realisator = BeautifulSoup(realisator, 'html.parser')
        realisator1 = realisator.find_all('a')[0].text
        print(f"realisator1 > {realisator1}")
        with connexion:
            c.execute("INSERT INTO realisators(name, movies_id) VALUES (?,?)",(realisator1, movies_id))

        try:
            realisator2 = realisator.find_all('a')[1].text
            print(f"realisator2 > {realisator2}")
            with connexion:
                c.execute("INSERT INTO realisators(name, movies_id) VALUES (?,?)",(realisator2, movies_id))

            try:
                realisator3 = realisator.find_all('a')[2].text
                print(f"realisator3 > {realisator3}")
                with connexion:
                    c.execute("INSERT INTO realisators(name, movies_id) VALUES (?,?)",(realisator3, movies_id))

                try:
                    realisator4 = realisator.find_all('a')[3].text
                    print(f"realisator4 > {realisator4}")
                    with connexion:
                        c.execute("INSERT INTO realisators(name, movies_id) VALUES (?,?)",(realisator4, movies_id))

                except:
                    pass
            except:
                pass
        except: 
            pass

        
        with connexion:
            c.execute("INSERT INTO movies (title, year, rating, nb_de_vote,value) VALUES (?,?,?,?,?)",(title,year,rating,nb_de_vote,value))
            print("insert DB ok")

        print("-"*100)
        
        
        
print(movies_id)
# Out:
# <Response [200]>
# https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=1&ref_=adv_nxt
# id > 1
# title > Les Évadés
# year > 1994
# rating > 9.3
# nb_de_vote > 2387274
# 28341469
# realisator1 > Frank Darabont
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a81a4a03d262> in <module>
#      60         realisator1 = realisator.find_all('a')[0].text
#      61         print(f"realisator1 > {realisator1}")
# ---> 62         with connexion:
#      63             c.execute("INSERT INTO realisators(name, movies_id) VALUES (?,?)",(realisator1, movies_id))
#      64
#
# NameError: name 'connexion' is not defined

# %% [markdown]
# # 4 / Création de la base de donnée SQL

# %%
#on se connecte au fichier DB
try:
    connexion = sqlite3.connect("IMDB_ok.db")
    c = connexion.cursor()
    print("OK")
except:
    print('errorr')

# %%
#création de table
with connexion:
    connexion.execute("""CREATE TABLE IF NOT EXISTS movies (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT,
    year INTEGER,
    rating FLOAT,
    nb_de_vote INTEGER,
    value FLOAT
    );""")
    
    connexion.execute("""CREATE TABLE IF NOT EXISTS realisators (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    movies_id INT
    );""")

# %%
#ajout d'une ligne dans la bdd avec les valeurs

#title,year,rating,nb_de_vote,value = "test",1500,50,5000,500

with connexion:
    c.execute("INSERT INTO movies (title, year, rating, nb_de_vote,value) VALUES (?,?,?,?,?)", (title,year,rating,nb_de_vote,value))

# %% [markdown]
# #  5 /Analyse de la donnée par requête SQL sur la base de donnée SQL

# %%
#execution d'une requête
with connexion:
    c.execute("SELECT title FROM movies")
    result = c.fetchall()

# %% [markdown]
# # 6/ Stockage de base de donnée en DataFrame

# %%
#mettre une requete SQL sous dataframe
df = pd.read_sql("SELECT * FROM movies;", connexion)
df

# %% [markdown]
# ### Visualisation du df

# %%
df.describe(include="all")

# %% [markdown]
# # 7/ Data VIZ

# %% [markdown]
# ### 1ere observation avec un tableau de corrélation

# %%
# tableau de corrélation ( si supérieur à 0,5 il y a dejà une bonne corrélation)

plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
df.dtypes

# %%
# Valeurs 
df = pd.read_sql("SELECT * FROM movies WHERE year!=-1;", connexion)
df

# %%
ax = sns.regplot(x="year", y="value", data=df)

# %%
ax = sns.regplot(x="rating", y="total_rating", data=df)

# %%
ax = sns.regplot(x="rating", y="total_rating", data=df)

# %%
ax = sns.regplot(x="year", y="rating", data=df)

# %%
ax = sns.regplot(x="year", y="runtime", data=df)

# %%
with connexion:
    c.execute("SELECT public, COUNT(*) as NB FROM movies GROUP BY public ORDER BY NB asc;")
    result = c.fetchall()

# %%
result

# %%
list_names_movies = []
list_nb_movies = []
others = 0

for element in result:
    if element[1]<10:
        others += element[1]
    else:
        list_names_movies.append(element[0])
        list_nb_movies.append(element[1])
list_names_movies.append("others")
list_nb_movies.append(others)
    
print(list_names_movies) 
print(list_nb_movies)

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = list_names_movies

data = list_nb_movies

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %%
############################################################
with connexion:
    c.execute("SELECT m.range as [year_range], count(*), avg(value)\
    FROM (SELECT case\
    WHEN year BETWEEN 1920 AND 1939 THEN '1920'\
    WHEN year BETWEEN 1930 AND 1949 THEN '1930'\
    WHEN year BETWEEN 1940 AND 1959 THEN '1940'\
    WHEN year BETWEEN 1950 AND 1969 THEN '1950'\
    WHEN year BETWEEN 1960 AND 1979 THEN '1960'\
    WHEN year BETWEEN 1970 AND 1989 THEN '1970'\
    WHEN year BETWEEN 1980 AND 1999 THEN '1980'\
    WHEN year BETWEEN 1990 AND 2009 THEN '1990'\
    WHEN year BETWEEN 2000 AND 2019 THEN '2000'\
    WHEN year BETWEEN 2010 AND 2019 THEN '2010'\
    WHEN year BETWEEN 2020 AND 2029 THEN '2020'\
    END as range, value as value\
    FROM movies\
    ) m GROUP BY m.range;")
    films_by_years = c.fetchall()
films_by_years = films_by_years[1:]
print(films_by_years)

# %%
x,y,z = zip(*films_by_years)
plt.bar(x, y, color='b')
plt.xticks(x, x, rotation='vertical')
plt.tight_layout()
plt.title('Nb de films dans le top 250 par décénnies')
plt.show()

# %%
dftempo = df
dftempo = dftempo.drop(['year'], axis = 1)


for i in ['id','runtime','rating','total_rating','value']:
    id_list = list(df[i])
    id_list = [((i/min(id_list))-1)/((max(id_list)/min(id_list))-1) for i in id_list]
    dftempo[i] = id_list


sns.boxplot(data=dftempo)

# %%
x,y,z = zip(*films_by_years)
plt.bar(x, y, color='b')
plt.xticks(x, x, rotation='vertical')
plt.tight_layout()
plt.title('Nb de films par décénnies')
plt.show()

# %%
x,y,z = zip(*films_by_years)
plt.bar(x, z, color='g')
plt.xticks(x, x, rotation='vertical')
plt.tight_layout()
plt.title('Moyenne des recettes en milion par décénnies')
plt.show()

# %%
df

# %%
sns.pairplot(df, height=2.5)
